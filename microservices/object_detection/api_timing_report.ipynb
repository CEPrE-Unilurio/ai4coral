# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 100

# %%
df = pd.read_csv('timing.csv')

# %%
df.tail()
# Out:
#       load_image  make_interpreter  set_input  invoke_interpreter  get_output  \
# 1157    0.154457          0.042480  27.422654          142.991156    0.404249
# 1158    0.108624          0.022112  26.071008          153.976212    0.518906
# 1159    0.571718          0.042435  38.686574          173.621930    1.179634
# 1160    3.809659          0.023860  52.871054          300.689550   36.929065
# 1161    2.324243          1.175339  65.211536          412.809615   36.722964
#
#       get_annotations
# 1157         2.874851
# 1158         1.692249
# 1159         3.543319
# 1160        35.158560
# 1161        29.184582

# %%
plt.figure()
df.mean(axis=0).plot(kind='pie', title='AVG timing')

# %%
df.mean(axis=0).plot(kind='bar', title='AVG timing')

# %%
df['invoke_interpreter'].plot(title='timing - invoke_interpreter (aka forward propagate)')

# %%
df['set_input'].plot(title='timing - set_input (aka prepare input tensor)')

# %%
df['load_image'].plot(title='timing - load_image')

# %%
df['get_annotations'].plot(title='timing - get_annotations')

# %%
df['get_output'].plot(title='timing - get_output (aka get detetions)')

# %%
df['make_interpreter'].plot(title='timing - make_interpreter (aka load interpreter)')
