# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
matplotlib.rcParams['figure.dpi'] = 100

# %%
df = pd.read_csv('log/api_timing_v1.csv')

# %%
df.tail()
# Out:
#        load_image  make_interpreter  set_input  invoke_interpreter  \
# 35158    0.245146          0.034315   7.422721           16.861069
# 35159    0.244646          0.033111   7.606719           16.902662
# 35160    0.243850          0.033741   7.445239           16.986142
# 35161    0.246794          0.034870   7.740551           16.876291
# 35162    0.249016          0.034962   7.406684           16.829866
#
#        get_output  get_annotations
# 35158    1.391134         7.608738
# 35159    1.319468        10.142434
# 35160    1.317875         7.037873
# 35161    1.321579         6.378435
# 35162    1.275450         6.490137

# %%
plt.figure()
df.mean(axis=0).plot(kind='pie', title='AVG timing')

# %%
df.mean(axis=0).plot(kind='bar', title='AVG timing')

# %%
df['invoke_interpreter'].plot(title='timing - invoke_interpreter (aka forward propagate)')

# %%
df['set_input'].plot(title='timing - set_input (aka prepare input tensor)')

# %%
df['load_image'].plot(title='timing - load_image')

# %%
df['get_annotations'].plot(title='timing - get_annotations')

# %%
df['get_output'].plot(title='timing - get_output (aka get detetions)')

# %%
df['make_interpreter'].plot(title='timing - make_interpreter (aka load interpreter)')

# %%
soa = df[['get_output', 'get_annotations']].sum(axis=1)
soa.plot(title='timing: get_output & get_annotations, as separeted tasks ')
